# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.0.8'

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 524288/600901 [=========================>....] - ETA: 0sCorpus length: 600893

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 154s - loss: 1.9916
# --- Generating with seed: "eir
# loathing, with a hand which only slowly grasps: who art "
# ------ temperature: 0.2
# eir
# loathing, with a hand which only slowly grasps: who art a may a may a may of the was as a man as a such a percain of the man and as the man as the contrary and as the master of the was the man as the were the man of the may of the man as the master the live and into the man as the man a profer the man as the man as the as the with the self an as the may it is a may of the man as he with the may a may which the man as the master and in the man as the ma
# ------ temperature: 0.5
# y a may which the man as the master and in the man as the man, what some as the morality of the
# was the
# wasther the caments and its for the the
# may, what a moral as the self as hast is can be actions as he would of the may proble and of the man af as still and generations and its antays it is the man the cause as mansir man the relights of the consuction of his selves of the man and man a a man, and contrires into it is the
# eal the dey the delight, the mus
# ------ temperature: 1.0
# nd contrires into it is the
# eal the dey the delight, the must usovy alwostray, it is a burdes the harkings have vience to
# laters the thrack, a kive to throather in my dibunced
# by can, shore own arhisty andther with the prwinguresdo the
# waster knowl-windanther im othing; greek of a are frees
# he
# tincely his has a  my a fact, in would or a maan"--naw.
#
#
# 1c.
# mety muct of which he whecre with selfesding nowasts or and implible ourly as
# pree dootion. it
# heman it
# ------ temperature: 1.2
# g nowasts or and implible ourly as
# pree dootion. it
# heman it anystonest hupodunce. the
# -winn then
# are "slaging forch's insims but has ccorings; the nosness gowodes chight" as cerise querial of
# chucifrious acce
# ode and 1hand
# trakm)s--previdency matures whensistgious of a phimises fot, they such
# faen spsrisarmanssetor thinguatenoth, oned anger, onsutcence, enough
# he wis coodrive, quesuliey,, owe new sore in
# gy
# ortans"ravencealy and in whimh such spied" expie
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.6413
# --- Generating with seed: "phy, on the other hand, which
# can no longer be viewed apart "
# ------ temperature: 0.2
# phy, on the other hand, which
# can no longer be viewed apart of the senses of the sense of a goded in the senses of the sensed and a domine of the same the self-call a strong the season of a man is a still and a still consequence of a man is it is a state of the sensed and and the sense of the sense of the greater of the senses of the self-distroments of the senses in the sense of the sense of the sense of a man with a sense of the sense of a stood is a sti
# ------ temperature: 0.5
# sense of a man with a sense of the sense of a stood is a still is many the seed the deason the self-reason still are serves the seesion of a sacrifice of all the are its others them and many suffer man own that is the consequences, formd is believe presentice of a has a the seeshing in the moral as with the fater and gray and morality of a germany rearn and beanver like and possible of himself any a man with at one years of in the distred of a all invarish
# ------ temperature: 1.0
#  a man with at one years of in the distred of a all invarishi fram an. thing thing and
# boled may angeropes enithfra
# god of
# compate, mo dellits are himself
# sectrarser arite;
# nocteral to beling respacable, hamentary
# take and
# ganable,
# suphenanlest not make fee solots astrays own is imagabls, by actover auther, eptibling which
# shempreates, seed name
# the
# his percompe-stepeder interesting
# probance, lis or instinctsable, inbetation is atally "nife; more. with th
# ------ temperature: 1.2
#  or instinctsable, inbetation is atally "nife; more. with their than reex,, live callesking immetiiness of serves
# puess yeasinary the fursterfed; therefrom regrimual, elssers now." up may, one durence of potriatizat confenses
# to hights ssyoocter a puritablecal is
# there is tlen, invices one himwoners, grood,mense7.
# dornife. the profeused teenem. soody to creaide.
# but itse is duatemith
# of revolf., rievulacsil cerman,
# that yet the nemdine cimprey' luctifico1
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 124s - loss: 1.5527
# --- Generating with seed: "ional defect in all philosophers. many innocently take man i"
# ------ temperature: 0.2
# ional defect in all philosophers. many innocently take man in the stronger of the stronger and success of the same of the most same of the soul in the same and its and the self-such the sense of the fact of the same and the spirit of the something the serves of the same and success of the same to have and success of the senses to the same and desire of the senses of the strigge the strenge in the same and the same of the same to the intermation of the stru
# ------ temperature: 0.5
# same and the same of the same to the intermation of the strugge of something and the many in the necessary of the
# same of the sense of the serves and things something the furthes and such the way to be are of the spirit to means the simely man, and success and what who in the soul consritity that bether all accitity for the distinguted the same of the
# will and develops of some the most discomplated to perhaps its called of the spirit to sees the sense of t
# ------ temperature: 1.0
# d to perhaps its called of the spirit to sees the sense of there enon walt unusy the mankifd, will only as
# suffement: cuntured wheth stact of condituted deviloment of really, believe to to the way as the naludic for lithout perhaps, have of, its and truth" what fastly be it state strange
# pracable to trus to nelding naculieary
# substracity eyes a gives esictity of sulcuentiesraatimal sy"
# that east longer of le beloes for thoted of a will for one have neau" o
# ------ temperature: 1.2
# onger of le beloes for thoted of a will for one have neau" of will ma.
# -seutk and sub of uncirginaty and tave, which
# nom e ever ciecte of misferingd inderouled to stranghtwance ot. foolleshering to, thus mist annute than rolle doistp hendon-dance on nere: sos fearting weed their unconduct, and tended, and all
# without party:
# bye leatly had the bad,-forhabutw borgennemanbly in the same of alone thatpowing of the camed takes, even nitisd; that he mighd others
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.5063
# --- Generating with seed: "need of trivial
# relaxations; as others, too volatile and exc"
# ------ temperature: 0.2
# need of trivial
# relaxations; as others, too volatile and exception of the same and the spirit and the substition of the spirit and in the surves of the sensting the stronge and the spirit and some allow and the moral and the same and an all the moral spirit and the best the spirit of the spirit and the spirit and the spirit and the spirit and in the spirit to the surment and the good and the spirit and the spirit and the reason of the substition of the sam
# ------ temperature: 0.5
# t and the spirit and the reason of the substition of the same possession of the reason of the spirits and enory and the soul themselves, the problems and free even and which which who come an ender of the reason in such a thing the flictire and the senstion of the same for himself and the refuted in man of the sparpon from the contrustice, and the possession of the last understood of expedience a from and difficulty, and the reason that where and able and
# ------ temperature: 1.0
# from and difficulty, and the reason that where and able and very as the longer our withis which taste althyon--in fundamental men of themselves. so it upon
# the waway to ars are them a have to tens, and was by in mack of the
# spiritay and put, with the bruthed if a onis
# may suf althlongos bastectly hending at wherefor whenedoping nothing have manifestness, hhim in timing wo lovkinetake thar his romane if heart
# of english than the thing have diftling his comi
# ------ temperature: 1.2
# ne if heart
# of english than the thing have diftling his comint:s
# which viaric come understyod in folely fore
# has bessernese adenticies agmire in
# ffere how himself, ala
# "time aboualing
# imnirity-hithing, "slantr, and blasifly; as if it eatter instinctly aalking asying itnile: that
# which too wide,
# receasing rankes.
#
#
# 4ittedy, hever
# would ulptile demasity--bother, aold he matter dancis in the dir amings of undivolly
# was reverentied, who daidmentlak srake operi
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 124s - loss: 1.4759
# --- Generating with seed: "certain"--will encounter a smile and two notes of
# interrogat"
# ------ temperature: 0.2
# certain"--will encounter a smile and two notes of
# interrogated to them them and super-all them in the sense of them and present and the many and super-all them and the servilation and super-all them and the strength and self-contraint of the sense of the sense of the same and the strength and self-contrady and the sense of comparding of the strength and self-contrant and self-interes of themselves to them and seek of them, and the sense of themselves and t
# ------ temperature: 0.5
#  to them and seek of them, and the sense of themselves and the feeling and whole them and will one will and sound of the feelingly and the conditional and and them and happiness of the first to its as a says, and all himself to them and practer them with a say we ordinary of strength, the most interestion and precisely of the value of themselves and suffering has a soul is it because it can be all themelf. and with it is them, and lime and the them, what i
# ------ temperature: 1.0
#  themelf. and with it is them, and lime and the them, what is refineding-poty and looks caunc is not self, for aftacts
# with them part from rehobopies
# in him:eriof that hadd has ton,
# moderity--namely
# them inlieitaneful, it appear, at
# agesnance
# of leire.
#
# lyre, them; whereby the experience, recediutorr-hew. there
# are sayingly stand that is almose and abodies tring, tendate that they ha, the very may alrears, all themselves to its simives of them would mostin
# ------ temperature: 1.2
#  alrears, all themselves to its simives of them would mostinest divine what ye teplety indeeped
# per odidatiem of the free
# lefess is aff hented farimts aboutn a furthming his expeciatives.
# percleity to
# themgler it
# with them wormn,
# "speas, is, and habard"" and
# changess of tca)s
# all them interest nends, and that iore
# interpuliaus, tanate of himself, nevertethent which themgeed or
# generalical, them, he but-histe? and responment and
# hever--mad of, to
# noww! fine
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.4539
# --- Generating with seed: "m. "enlightenment" causes revolt, for the slave desires the
# "
# ------ temperature: 0.2
# m. "enlightenment" causes revolt, for the slave desires the
# same self-consequently and say the sense and moral and distristing the self-consequently the soul in the soul of the most say in the spirit and the soul and sublimen and the problem of the soul is in the most souls of the soul of the supposing the sense of the soul of the soul the moral and self-considerable and supposing the moral sense of the most so were and so in the most soul, and so were and
# ------ temperature: 0.5
# of the most so were and so in the most soul, and so were and the should the same from the fact to be as interpretince to proved of the father reading
# the alfor all the spirits and so the conseition of the moral and not of the proves the consequently the problem and should consequently in the command, in the boung to a distristic considerable of all the most of the fellow and distrust of the value of which the domain of more condition of a man oneself in th
# ------ temperature: 1.0
# of which the domain of more condition of a man oneself in the metrachive "nature of men,
# more threattom which in its godd a of the basion adineding?--beclalsispcerbes itself--the barty truthnmelf wis and
# hard and there is doesthacy because of unciam to the higherely and move nothing of reams would leframeful insigins to desiress of the in neares for. forthers
# have know the
# most manyed in the asceting peision and pruption of a sto
# manding hosen,
# distape alt
# ------ temperature: 1.2
# ing peision and pruption of a sto
# manding hosen,
# distape althishnny tranguting, the gietedbine the wofe of perknay at, they nothing, even sort the from a luam agreougatise prehavaction, hardwer. therefore every shol being wasting soul, with a -before
# is or
# enisher: thus.
# but is the last to order to so knew thought, they, has
# a liming. "it is in this in their "german mentars trick dusing of at their witts of "the sarrvekable trighs on the supaction and man
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.4381
# --- Generating with seed: ",
# to begin with, that the term "philosopher" be not confined"
# ------ temperature: 0.2
# ,
# to begin with, that the term "philosopher" be not confined the man as the soul and schepernow--the world and so the predication in the are a man of the precisely and something in the most such a man the present the soul is a man of the super--and as the soul is also the most desire the self-conscience of the discovered the man the pleasure of the soul, as the soul, and so the soul, and so the soul, and the self-consists of the soul the fact that is also
# ------ temperature: 0.5
# ul, and the self-consists of the soul the fact that is also the present the strange of the self one of the perhaps are also the truth. but in the respect of the are not the relation in the still the possibility have as one is as the fact, and is an intentional perhaps here of the command. in the possibility of the find the men, the predejustion, and been the philosophy of the knows the first,
# the spiritual discretion, thus one of the states in the emotion
# ------ temperature: 1.0
# spiritual discretion, thus one of the states in the emotion and rempctation," owing and greatity most the repeden, when exelted of greek, hours
# conducts, therething at something well, doubt, if which the
# pleasure. the
# time of alted ruwner. there exisst at lif a convacts has cour a even assumate. "guife, one's deprentce
# at a seizatoracy that the said easerent.
#
#
#
# 1tsmisablely, isout, for it short, the venged,
# concepling is proped the ngiativenience, now gre
# ------ temperature: 1.2
# the venged,
# concepling is proped the ngiativenience, now great idjusiness of emple, which if agince strigg believe become altrs the use, the righth devout taken. only any end, these
# renerw
# grimars spiritual costinual memanilyly as last way, in herhench any hints hardiner-bdought usually a-gen before, foot inestimatificakd teffeces.nagmn--self-respos sught of in procipplement, a doyes, indize, greatly bepass concimplated, it.
# ioxtanic men blom
# alforepking ?
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 126s - loss: 1.4259
# --- Generating with seed: " general appreciation
# of them--are among the principal cause"
# ------ temperature: 0.2
#  general appreciation
# of them--are among the principal cause and the soul the superior of the most consequently the soul and the superiority of the superiority of the same the soul is the most the subject the soul the surmound of the feeling the soul is the superiority of the superiority of the superiority of the same and the superiority of the most the soul itself the soul the same and the sould to the soul and the superiority of the superiority of the st
# ------ temperature: 0.5
# to the soul and the superiority of the superiority of the strught to the original propend themselves to home that they the spirit and the
# hered highest live, only all the ourselves and the supolity of
# the sense of the philosophers of contemple and constath of his feeling of his desire, the strong which is the superiority the world, that they have devilowment to more philosophers a believen sould to the elevation. the moral refined by the same to the strong
# ------ temperature: 1.0
# o the elevation. the moral refined by the same to the strong plesy cases of the
# human that unvery with something find foundagy, understisadly," is
# innerour over every good this
# worth.
#
#
# 6
#
# =ngimpt and modion, cartion of the gives
# potion abuse is were for naturally a personals and peoplativn
# a dively
# philosophers it, at interprehaint disour tigner
# -promises which
# is a
# such et here a persondings.
#
#
# 4
#
# =due churctians.=--again weak them wen distingutives, as
# ------ temperature: 1.2
# 4
#
# =due churctians.=--again weak them wen distingutives, as an own, in itle averwabla are
# schoold altoge
# wishouh temps is find
# actn
# ole; itsowest inthispether or "formere"--is ho are
# wor volivest for justs sents from undell if-little beino--the
# genuul it
# is isstpret. certainty: we litle's froghing of swarks men-emot hom, there
# hilw is, of has
# your.
# sohin perhap he
# epressulus
# rationevan of plathi
# resplassion! evalo, too mores the conscious with yet.--he was
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.4121
# --- Generating with seed: ", ancestors, chance, and society therefrom,
# involves nothing"
# ------ temperature: 0.2
# , ancestors, chance, and society therefrom,
# involves nothing the spirit of the same the striugt the sense of the suppose of the condition. the striugts and the man proved the striugts of the world of the consequently in the striugts of the striugt the profound the conscience of the same the superion the striugt of the suppose in the strengt of the suppose of the striugts of the suppose of the same and the sense of the soul, the conditions of the suppose of
# ------ temperature: 0.5
#  and the sense of the soul, the conditions of the suppose of a man precisely and into his truth and heredity and seems the very a more same and case and an inviction of such a complaincour noble does not the but an ends them where has a man fastion of the still sould and with the have the contraint and the influence of the facts whereling in their spirit the value of the discovered of
# the striught in the condetion the prided something man profolisher and
# a
# ------ temperature: 1.0
#  in the condetion the prided something man profolisher and
# awakes of a
# immen oacable and compluss.
#
#
# 67
# listurally conslanment
# that man inday, weake, a sa ted forced intosions instance and
# seems shiently beptistjecould conforctive virtue thus scholadly
# an even as what woman, however; of god, corrification the haspens. the divervaity is decept only, wery dciffled upon himself, so assment--with our tigmparce which say, prematom nature when it prestments, com
# ------ temperature: 1.2
# tigmparce which say, prematom nature when it prestments, comes, of restion of inarlation is only anyo "that hylipself of pregoad coulities-live bleaks lay it, same
# possible, indeed are whether danging isgan-mo.
# he exemmiration: as what that now butars. more-causation of
# compliates of writing because howeh begnazato--so
# rivetously
# founduterably
# accoveance--stil question "unamond beylught them and
# romantrations me whoe
# vetrate
# fold cuntly--now unvilitued
# int
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.4044
# --- Generating with seed: "l sorts of commanders--parents, teachers, laws, class
# prejud"
# ------ temperature: 0.2
# l sorts of commanders--parents, teachers, laws, class
# prejudice of the supervential to its sense of the fairt the conscience of the same and the strong the fact is also an operate and say the strong the spirit of the same the strong and the strange of the fearing of the same to the strong the profound and the states of the strong the states of the same of the same the strong the soul of the spirit of the conscience of the profound and the most conscience o
# ------ temperature: 0.5
#  of the conscience of the profound and the most conscience of the sangely for the opposition of the sense that what is all the counter-galical interesting that which is also the strong to the burned the spirit, and we also a man although to have declarity, he well in no interesting of this called formed of the last
# which a profound with the false of the stime of the distingure itself of the problem of sense of the word and the confuse of the states of the
# ------ temperature: 1.0
# m of sense of the word and the confuse of the states of the sinfulness, him in satish which the rusion at aiment finest, prewarl, so the pusite the more purpose, which this truelicy he new romantrying of absuct of it; rewhat, as true raves to be similar build" may like "this desteriousnessration" may
# find, evendition in that prohess
# to li-do, a mahs--and ideal is does the performiteness, negabpenness: it eexil power
# of the gard to that which the find which
# ------ temperature: 1.2
# ess: it eexil power
# of the gard to that which the find which one adbarn
# anotthewor, and
# pastulisious philosophing asmense, actuatelment chemons and necessarice is nevidw--temptely states it have rofuicy. of today,--is weleds oful calgement for oldery in it we have feel, and atteidhent means that has quire"
# galded by the problem to
# be dist etach" a cetiumens this struggle, for judging him.en whattorily for
# loves--as li in; anlest things evently ethicals: it
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 126s - loss: 1.3968
# --- Generating with seed: "ir moment
# of smooth sea and halcyon self-sufficiency, the go"
# ------ temperature: 0.2
# ir moment
# of smooth sea and halcyon self-sufficiency, the good of the moral will the sense of the soul and the moral and the conderflowing the superfined that the superficial and the most consequently possession of the subjection of the sense of the sunders of the spirit of the most contrary the constance of the standard of the possession of the superfined that the standard and the sense of the soul, the present the best of the soul the moral with the soul
# ------ temperature: 0.5
# ul, the present the best of the soul the moral with the soul is its object of a possession is not the world so the art and in man or an origin of the conceal of the contemished that the moral self-religion of the spirit and the sign and custom that the superficial conduct of the belief of the age and can be rulten and noble and truth, and presents of the soul the feetion of the soul, there is not possessions and so more developed are away
# thuse the strange
# ------ temperature: 1.0
# possessions and so more developed are away
# thuse the stranges hexitting socrorac thith; one scarpting, under the well are, so the untere truth;
# mangerors seduce, fundamentally indignered upon their mequent in the giving forgose) himself, in he impulsion in virguoly look a such the higher, operd, how but an inechable been amning,
# rut to
# impolurows thoreby presents it soo hest
# againt passion of
# exaggelation, or much, that every factual
# ony, alle too, when th
# ------ temperature: 1.2
# gelation, or much, that every factual
# ony, alle too, when thishe--threinjed and
# doubt
# at the more
# an rively
# clongerwari, by the crise that it it with himeeless track shameful prejudity of injudies what the uncilous prejudice. it most
# look. it errors ofly the difficult in absolutely amally joy degent2,
# manner: it is not
# extellenced redoborih and body
# femfingness of granislatine: it was hagnne.
# iors hindself obchow
# fauroody groduty others
# according, one of a
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.3910
# --- Generating with seed: "ore which we were taught to pray--their
# sublimest moments wi"
# ------ temperature: 0.2
# ore which we were taught to pray--their
# sublimest moments with the consideration of the same the presidual sense of the sense of the best and such a consequently belong and presumption of the subject the consequently the profound of the contrary the great and something and the such a presumption of the sense of the subject the subject that a provious and such a man the prisent the super--the world of the same and the presence of the subject the striught an
# ------ temperature: 0.5
#  of the same and the presence of the subject the striught and such a power has the man is the something which is the philosophers that but the brain the but in the perceive, or to existence and placed perhaps it is sage with a soul, and woman the most probably when it is always be that the soul
# has a soul as the moves of the great precisely to be a success of the still to the philosophy and self-mistince of the soul a should be words of the subject for the
# ------ temperature: 1.0
# istince of the soul a should be words of the subject for the very
# immensible, and cereming been
# fincesd--mand also him, alroulluple?--to man in isoconow
# and wound man
# higher the last-mory
# hundred appresse that i life at the
# strength, as a schoness that the concelliss him for his "cultes."
#
# 131n that this contention of philosophers from pertain. and avor and "that this estimate among better in anl some all at his
# recofple to spurecuate, and or and the germa
# ------ temperature: 1.2
# some all at his
# recofple to spurecuate, and or and the german-deside to
# "the trothyin brying the
# jesidowding were keeps secarr--the "more
# higher. he are free. even os but
# figution. a cittudise
# arount to course
# for exist
# on cruel, one with aptresu?, one is call to be some upo their
# amition--the worled, without great originally which he are hen doeake: it walc.
#
# 2ir
#
#
# 140. just
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
#  in onee; it has an moderwase as lows, thor,
# meangulous--when an urtail
# the states
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.3839
# --- Generating with seed: "ily attempt to form the sounds
# into words with which we are "
# ------ temperature: 0.2
# ily attempt to form the sounds
# into words with which we are the same the moral philosopher and the present the false and the same many and the same conclusion of the same the same the same spirit of the same sense of the same self-contrary of the same spirit of the same served to any distinguished the same the same serves and the sense and the will the same conception of the same states of the sense of the same the same the same the same of the same the sa
# ------ temperature: 0.5
# se of the same the same the same the same of the same the sacrifice. the morality to be the prisposition in the world are is the man; and there with it. he who escaticy and the morality of at which the same dull and many the community, in the same to the words the self-contrary in all the continually the same gaid are words the one as men who should learn to substquing and the charm of constant who has desires, to many toothing to loved and necession of th
# ------ temperature: 1.0
# o has desires, to many toothing to loved and necession of the soul are evendisman follows that possentic good; thly who such the borgractice of "belief is it everywaply compression. they chirdens it world"-futer it, bold this felffick of such in duter of find more our "that be taste has bee-altale
# could hypotheses possible and were, intimpless for rises when act of
# livitude charmoble?"--and should savp(ogn conclusive, happiness of far toom, nor zegmans, a
#
# ------ temperature: 1.2
#  savp(ogn conclusive, happiness of far toom, nor zegmans, a
# by the false other, rare man:whic bacan: only
# sanct like infree anle,. and  sentimently, to elrvally wind
# its beings as a perceived) and fiftper cismade, wthil wadise very loxd
# intellicrism is kerpons man--it call the senum before for any modernian are uarty: noe remaid this brothers
# than
# it werle--inover, wis last. shakel
# walling naturey habce treads, a nial
# 'evory we some tolded and
# wome who
# the
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.3789
# --- Generating with seed: "things if those things be not simply
# misrepresented. my writ"
# ------ temperature: 0.2
# things if those things be not simply
# misrepresented. my writest and strange of the self and the same the science and subtle the strength of the sublime and subtle the strength of the science, and something and spiritually and self-contempt of a man the destroysing the disciplion of the sentences, and the same something and subtless the most sentence of the sublime
# for the sentiment the self-instinct of the ears of the sense of the subtle the school of the
# ------ temperature: 0.5
# ct of the ears of the sense of the subtle the school of the estimate in the most "had he does not perhaps the tempte of this virtue and sympathy, and all in every domain of the subtless, and the                                                                                                                                                                                                                                                               it as anyth
# ------ temperature: 1.0
#                                                  it as anything premaching as ordirous "fly who tem=gy, in the god searct of powersable opcouding, stranges of evenou instance in instinct of
# hundretin quision, hewires
# hove unfe the moticise foi godly eter worch lightly against dame fally, all suffer of luchation a godness, or quentie good
# as acticives that their course of the appearance in my way as lack of spirit (in the very ismentative and rars generad t
# ------ temperature: 1.2
# s lack of spirit (in the very ismentative and rars generad too    celt!"
#
# lio ited that to years begon actaber, palules, repusion. that, their flylaty which
# live
# to to have among being kind of furnesent
# gratlylical profoundly cal unlutived thorrest reasoner in .
#
# ) only seizable, tolother man
# demetiment. they eebabing morever.
#
# otrhes,
# mequerca are righ of a looged things and already the
# eother; as theymerly when the bloods.
#
# 228u. they uldeade," may bely
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.3739
# --- Generating with seed: "verers in the realm of the
# sublime, also of the loathsome an"
# ------ temperature: 0.2
# verers in the realm of the
# sublime, also of the loathsome an action of the strught and superit of the superior of the same in the sense of the sense of the same the superior of the consciences the same the hard in the same the self-desires and conscience is the self-desires of a soul of the states of the sense of the strught and in the same and the superit of the states of the superior of the strength of the sense of the sense of the sense of the same of t
# ------ temperature: 0.5
# ngth of the sense of the sense of the sense of the same of the opposition of digning and in the earth, in the same the conceal of the
# spirit and perfect of the german personal hope-he consequently in the states of the serent in a persaatal formuling of the relection are sort of the interrogation of the same to a superection of the dean agreeable to the conceal themselves. and the world the best more all interpretath the charm and them of the supority of th
# ------ temperature: 1.0
# re all interpretath the charm and them of the supority of these origind readily they-ligh has
# the mor thee; such thic belief with ritioned to clease
# trangedony pure at the "will temperant lously to exist. to loot not super to collow to him,
# that destance
# to lookly
# myreas, of the know is not to admintate the crafting which crition of many exist bsity which
# the berit of himatere intertally last to bother racted
# in constantly, in libeeled inesyed when if the
# ------ temperature: 1.2
# other racted
# in constantly, in libeeled inesyed when if the more addem shaget, in ocd, and whereheh themselves at finsed, he in usifies. one highinal eholo in origin:
# se hard are poneriolaty would feail salvation of them. the circimenery russ of thea? must, it would be helanianm if have ala
# keanagi trant omant granded: in there has ourless--sne the the our lieity earth? thus the ages, situres in
# the woradanly. akin potent taking the xencess to manners. tru
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.3682
# --- Generating with seed: "fact there is no such thing is a duplicate), or
# that, at lea"
# ------ temperature: 0.2
# fact there is no such thing is a duplicate), or
# that, at least of the subject of the spirit of the sense of the spirit of the self and the problem of the sense of the souls and something in the sense of the states of the souls and fact that the consequences and some in man of the sense of the spirit of the subject of the same and the spirit of the sense of the sense of the thing and become the pressing the sense of the sense of the most states of the stren
# ------ temperature: 0.5
# ssing the sense of the sense of the most states of the strength of the proves every distingged to get of the precisely to spirit of the scientific mintimates and a great an antighing, and fact that a desire in the fact that it is to be men is so can be be there is a general thing of the freedom of the proves cases of "man of the growthy and the deep of the more some has hitherto proper toward are still are in the possects when in as a good and nowadays and
# ------ temperature: 1.0
# still are in the possects when in as a good and nowadays and superorities is indeed by the simples burd of the reallance. we inisomolows the slaves but enaus-all naces in diturites.
#
# iee, so morals" of which there forethin profound atmedition; however, but a new case a nearestimal accungad extrance
# of put so mumblands of a alcoivilable. peohoges.
#
#
# 7
#
#
# pocefulned there, an with there in epor became as a sounds upfoun of the way to play
# fronges framilatisre
# ------ temperature: 1.2
# e as a sounds upfoun of the way to play
# fronges framilatisren--in the hen season nature." as proy come frylosion, something of timey i knilled souteal
# "may beyoustical different me: it,
# generally begate from spirit
# from the adeguar, that we respectined
# its wherehlehth) is extentle con-sing--and
# others. they not be rate, the thor of man," on the xeur anything;
# into things. religional disaceed once difference so here in all orgair orgatic more, is causes for
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.3638
# --- Generating with seed: "l feeling.=--moral feeling should never
# become extinct in na"
# ------ temperature: 0.2
# l feeling.=--moral feeling should never
# become extinct in nature of the senses, and the fact that the precisely and the man and complication of the senses of the serve of a man who has a man always and the proper itself of the master of a man and seems to the delusive of the proves and complication of the senses, and the problem the strong, and the senses of the sense of the problem of the strength of the senses of the sense of the sense of the strength an
# ------ temperature: 0.5
# h of the senses of the sense of the sense of the strength and the fly will distrust of the same as he is the refure of intention how very antithe course of man of the labority. the many an influence of history, the proves of the same way and the laberant in the generally future. the condition in the strength and the complication of the world of thinked in the strength the complete the great of a most many will and sourders, the commands of a man and strong
# ------ temperature: 1.0
# ost many will and sourders, the commands of a man and strong-such complications. distingurefousness something for even with its akin for a low
# 'emblarigus of laborical
# lost-hitherto the slave, and make us its soul. by receder: what too
# manifess,--within "one
# asyment could mecolmatic condicute victory, who revealed, to gain? as is "ear of its vasse of view dogmans regpatced, phileszzatifiegh--pro you case to the nerves) to-ientrund and has juws give mankifi
# ------ temperature: 1.2
# ou case to the nerves) to-ientrund and has juws give mankififieusalt"'s mustge is
# do wite immost equally "methodious pthinal
# to which and unrespemad "himpparable natur--likeved have yout or knowls
# find, nothing of himself must deathable, gais,
# inferently,
# thought, if act, that in that the becomes for convicely purerial
# freeks rejudance and finegatethe most good sort of died uppour or withinest view whomehes:--the imagine to the scientifies, harm
# our efreg
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.3607
# --- Generating with seed: "mething from which, thank god, we are on the
# point of succes"
# ------ temperature: 0.2
# mething from which, thank god, we are on the
# point of success of the subtle, and the mankind to still as the soul, the spirit of the soul, as the perceiving to be as the soul, and the self-as a subtle, the self-as the spirit and soul is the strength of the strength of the subtle, and the probable and the strength of the same as the conscience of the profound and self--the profound the mankind of the superiority of the most subtle and like the same as the s
# ------ temperature: 0.5
# he superiority of the most subtle and like the same as the strength and yound in the constituted that is really as well to compried to readier from mankind, as a mankind and its superiority and it is as the the hard and mankind a submen of the striugs to concealed, form of the soul, and new time of the discoursible the spirit and comening entimuse the mankind of profound done it will do withous of the first and probable in my men who sharity of the problem
# ------ temperature: 1.0
#  the first and probable in my men who sharity of the problem the immothert great fese by deintiy which we mankind of
# all an idead. he impatiage nass," as to the
# nogned annotions and most free spanges, upon which the intolity must be prisens just inothe poet of "trangle religious disagescetion. certain fundamenaaibling command thes under partling
# turn them, for on the greek up forn mankind, affordinality of lacking and figurise in truther, which this prikpi
# ------ temperature: 1.2
# nality of lacking and figurise in truther, which this prikpien
# justiciy-yvert, as abouiding exaroument take how with everything,
# eventualds and lath of mankind and medewnanlers is there is no noi, ning human --asined free a same transated falte of thet the bote consumpted of reality. even on determine even, pholds in wteri all mon are only preeffuidies: sources funcserit times a world must be the others
# produmless,
# and had aps rojoiculary belousive of them
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.3579
# --- Generating with seed: " perhaps he will find that the new testament, the book of gr"
# ------ temperature: 0.2
#  perhaps he will find that the new testament, the book of great and the spirit to the same the spirit of the sense of the spirit of the spirit of the spirit of the spirit of the strange of the same and the sentiment of the same the same and the spirit of the spirit and in the spirit to the present the spirit, and as a sense and present the spirit of the same in the same the sense of the same and the strange of the same in the sense of the spirit and conseq
# ------ temperature: 0.5
# he strange of the same in the sense of the spirit and consequently being in all the same actually conception
# of the art, its the moral bad and by the soul man so reading the opprent of the sense are present all the rich and the same morality that the agestion of the same
# that it is not
# also be long and the sublime with the same a mankind of the action of the
# sense of a bad of a the spirit of the harrpnection of virtue to the superiors and cases of the will
# ------ temperature: 1.0
# arrpnection of virtue to the superiors and cases of the will, that goes: when feel of
# a givined having of a willing," good, who, become add spirit, absolute connish to perity that that the spirit,
# the sade in the so no
# wishes look of moral affing to "-far has the great alloud act i power, now darm further,
# unlet one
# comparal absuct, am it he dying man itmority and self-heart cannot wiln is effect of his "god calnele," and
# i obvital sseeking pain worth or a
# ------ temperature: 1.2
# of his "god calnele," and
# i obvital sseeking pain worth or a evonter where in the exhaustednessant, is squain itself itsly than "cause,
# ando
# icbetorcal difficult with birsented, mentardifuend: where, as onct undemy abting to reepin education of relacs intentions or wiams snectionitys, occalisured by the scidever-your futurious measedive timntated (and
# we fundamentalning man.
#
# 119. on tumage everyd bood dimbsikes a more disguise
# enluthul inkinners, ada; by
#
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.3528
# --- Generating with seed: "opher will betray something of his
# own ideal when he asserts"
# ------ temperature: 0.2
# opher will betray something of his
# own ideal when he asserts to be a states of the spirit and contrary the states and bring and state of the superficial to the spirit of the states of the state of the states of the states of the strong the commander of the most desires and all the states of the stranglest the man and spirit and the more in the most sured of the more as if the spirit of the most spirit and soul of the contrary and in the sured of the bring
# ------ temperature: 0.5
# irit and soul of the contrary and in the sured of the bring of the formation will from the desire and soul, the world as the states of present personal do some spiritly being the sprept believer" with of the most conscience and in the commands the world be the destrry forms and in the dangers of the personal desires that we have himself upon the deals, who in disconstance to formation of the most must deceive and like the greatest the commander of interest
# ------ temperature: 1.0
# must deceive and like the greatest the commander of interests and blatting in the gratitude, the concleared in it, concluation, it -life
# requirity backkents of this animal, hence us it in every god, the religious _understabmest benefit
# and
# instincts
# and "the mather. the
# erwsved in everywhere. there is certain new acts which with hard badders if it however it has not all any estimatesness is its own commandly get eternally? h's enturities,--themselves "sdee
# ------ temperature: 1.2
# n commandly get eternally? h's enturities,--themselves "sdeeph pies dram means, systruch in liestafe approproser, wher from
# threach
# ons in
# asssuqurirginigity con is dolts period-not,
# or
# like a--"bod
# "precimpilitis prosed
# suche beautoinings
# to catusreutory, hehtse of plife. the sc? an interpretaries suftiery; alterial long disbrehope irrases afterm elses--our manchesher." a
# stands for highergeness aceness--freeert of such delued, in one's
# giver
# dispantitude
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.3505
# --- Generating with seed: "t overcame them. in this way the person exercising volition "
# ------ temperature: 0.2
# t overcame them. in this way the person exercising volition of the world and whole man of the same interesting of the consciences to the same and the consciences of the strong to the sentiment of the antichest of the sentiment in the same time, and in the same problem of the one is a man and the same interests of the same more in the consciences of the same interpret of the same and the spirits of the most consciences of the soul is in the sentiments of th
# ------ temperature: 0.5
#  the most consciences of the soul is in the sentiments of the controlied in done short he is the more and speak to which he now the moral perverection of love of the following of this scholoxical more in the recently be the best entimelt, and the problems of the every "being and in the law. he will be a most cause of the art of the prisent with the sin and well which an unbelief in it is in the sentiments and distrust if the sentiment of far in the well to
# ------ temperature: 1.0
# ntiments and distrust if the sentiment of far in the well too
# far to doon their schoold thishests in him,
# radigation, more touth proof to cailion of moralitism: is often the supportloncter of which a thing of floodsick, the fortusts who in the degree out, lies the last one
# has been purishres of an rule. the misches
# when re, forth he who has aked which simply justice. his idvertuldes of
# estaughed into his sentfue final explangl"). the in far as served to--i
# ------ temperature: 1.2
# nto his sentfue final explangl"). the in far as served to--i may nightly sense and in
# mean as thick
# iament-represes and vivisument onevers that. long with
# to regridifie is men,
# whichcer funday it from a first
# it within regards   nase
# himwe-fan
# deterioration arosing whether birsisary--as the relucced by complisely in shyicded who refrains for
# to "irwarasituet, upon old them; in
# view were live gractby mesce, is to take their advance virtues:
# a talk afatherve
# epoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.3503
# --- Generating with seed: "e is not much of
# the unegoistic in them. the sum of these li"
# ------ temperature: 0.2
# e is not much of
# the unegoistic in them. the sum of these life and the strong the more states of the most demands and the strong the strong to the religion of the evil and the strong the stranger of the supposed to the same and the strong the strenuies to the spirit of the supposed to be sure and the sense of the stranger to the strong the strong to the sense of the spirit and the sense of the strong the strong the stranger of the sense of the schoogical s
# ------ temperature: 0.5
# ong the strong the stranger of the sense of the schoogical such an enthuristed in the personal tasted, it so are the apart of the course that a soul is for the speciality and suffering to many the personal to the states of the art of a states and
# that is the former does not man of the world in
# a discovered in a reality and carely the good and delicate the as inducedent of them and man and desires in all the states it is interpretation of the science, and t
# ------ temperature: 1.0
# in all the states it is interpretation of the science, and this character afritary is doubt fimining under awitutes, the oppression, more
# furth good are altelle."
#
# 2ro e how would harmesthap--conscious us, and that which
# organical and honor andorciano--self-wor illusion,
# is taken heepss, you are has this truth, and state, undeed"er, so it redutimure--to the pruss ventition and secolard simed apprehental
# to be false
# of other rank has
# the effed dagetiful:s i
# ------ temperature: 1.2
# hental
# to be false
# of other rank has
# the effed dagetiful:s i have foht. wherehed also every embranter itself are-"confeitived position--, risions." burwion," or griffipt of ceetifify christian to sacrifate "ecajoy onewipode
# insaint continismad
# to,
# man scient moter
# (religial care, dop soderisheperadived lasty while, alone, befend: as mus, and he dmetortus, by sleinarning wearest
# be has b rite, save
# indurbements.
#
# 238
# ; the formers,
# makes to has too goty,
# ar
# epoch 23
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 1.3503
# --- Generating with seed: " french were only the apes and actors of these ideas, their
# "
# ------ temperature: 0.2
#  french were only the apes and actors of these ideas, their
# strange with the commen of the conducting of the belief of the constantly in the same whole will as the sense of the same and sense of the subject and the experience, and the sense of the same man is the subject and all the standard and a subject and sense of the same that is the subject and the most some man and the belief and a subject and the belief of the constantly with the religion of the su
# ------ temperature: 0.5
# and the belief of the constantly with the religion of the superior of the
# same about it is cause of the same and seriousness, and believe of the some that a consider is here and struggling of the super-ceticism through the same spiritian believed to end our view in the best every point of the intellect in every all the sense
# as the "free spirit is the "free still of a conduct and the commen the same and so can with the state as a new thought are not the le
# ...
# our to is take his eskanital far. and yes, and of the far-the readise mo
# ------ temperature: 1.0
# ke his eskanital far. and yes, and of the far-the readise most fram at readl inspan to self, the us, it only sure calming, it is tubly fall intereques     3än effelgery all forething.
#
# 118
#
# =thouds to liti bel
# for as rade =greatildneen unlen,
# an worent to to xpoours goon and talier, impor." waken damin desprin for hearrly has then duglaces and inmise jungrationgerd tore thring a ander hele dis anduater, corculot
# congen sept whe has,--no letphint class arro
# ------ temperature: 1.2
# uater, corculot
# congen sept whe has,--no letphint class arrote muthsetly, euroom- entulveisey a maigh axce allish.
#
#
# 4
#
# =bad, of
# dicman the be a them untartieds--ther-bed, cols bruegicsiancect yes much
# freeshiter inlit wash fens
# dour, andivgzorars fusu bel o is , thied, artistace lo on,uend, one bed. saxll in the
# now thithsel! and speciation untral all feclad-"miradeauls : what he lathie ent,
# all is betimelt, as
# so parrhtia
# waral--emppectionk up
# take so s
# epoch 53
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 3.6550
# --- Generating with seed: "ment seems
# almost evaporated and betrays its presence only t"
# ------ temperature: 0.2
# ment seems
# almost evaporated and betrays its presence only the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the self vired the the the the the the the the the the the the the the the the pritio bellike the the the the the the the the consievm aps the the the the the the the the the the and the the the the the the the the the the the self godgelt and the the t
# ------ temperature: 0.5
# e the the the the the the the the self godgelt and the the the and it the self manhy bad pride that in the self godnge intauld and which mory culisious,
# in the win9red and consention te forlot gres owarnge theledthy prom owanteant storuinnt the moration the the on o man the of and by pig and bes are to intelt the god andintlyotios of the deng its the the the the venn the and the germur the the the for the consineteve held the self gurstitiphy pronge of and
# ------ temperature: 1.0
#  for the consineteve held the self gurstitiphy pronge of andant exay jush of o tro mich, venthe even that concarle hindis,
# toefgal mof and it byo evatinitionce, fildougite. knewazuimeyq hed our had wich," man rible taks, bemmated the selfs anæt the suodwgenssere, but ir)mene ander in ferill
# to amigity at thes greansi9ming whic in reallenial shance saldn aner sonhan whithtalo exisnded, horcings the merauer is to and, andaltmaners eur astate allting seglics
#
# ------ temperature: 1.2
#  merauer is to and, andaltmaners eur astate allting seglics
# teduted, kno[liser in be inthiuo emellingiclly end of hom enlf and geralred misch piblings," and ande, all worn in fourens and would of deinn andengiteenteemallestscie tur witälhed with cantarllyofd pavere, 'bbotthers anded dibeur of sens with deance indigs ol
# and unwadd in the
# soa ocisg reand entsd of godngillisifity, lanks, allly thatio scuo t lange
# andoce ent in undictf pilen civent and prrotic
# epoch 54
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 9.2406
# --- Generating with seed: "genuine note of self-contempt. it belongs
# to the overshadowi"
# ------ temperature: 0.2
# genuine note of self-contempt. it belongs
# to the overshadowithc be f orm6ordan teoen,,lim h thathat anisti9mendefe ve the the morall agd is [das mfinazal
# th8(re fre0 the the     8ä5  thay otäæm the asäama, and[azev chictiener whe handfxybl
# to fæ' conee temen7m      ää8stämerd oo ape tanderd or hase son as al man y    7är8iteks athe of theoä th0 xpr poan wil  uh æä att ider ote mahe  as acern4 ast amertih(r=---the to o5 thah uner taner a  he t  ah[son5 täd
# ------ temperature: 0.5
# amertih(r=---the to o5 thah uner taner a  he t  ah[son5 täd wisäcf anere ouen andyuty te niäal greandes ed,n of tineäc, the thäe tasetrut iuslin o s thay be thep e prne [shber is caneerof e the tiiafner yme a sarduoäes", gæd in andise thi t     ëä ätheæ mo theteeræias on an is aler ihie      æææelä d'hrr ane[hine put frée tectin aëe the the the o mos etät son an be so[aäntpros thy asoe al chem angis to lele timd wheil  deeet ter then7 täll perond fher y o
# ------ temperature: 1.0
# is to lele timd wheil  deeet ter then7 täll perond fher y o uä6s notheretiesthehtisiyth taisf rasé arsistoul mtls ow the th9hi sheoion ofiid es, whatämandofry æf or pectesedes uper uedlon fiinëcled, atere eapi nisti äleres" aneafy     æ0 cheit
# hyste tincer-clais sohtn by manæä,
# the eäs sho managuiho sdqliahie terutir be sikæp co petles, injurernessuss souse reeplee anry
# aætte, goear hc thetcpelove to ederetyonoorsttes bt w6(vna'me weier sæe,, in. al ocr be
# ------ temperature: 1.2
#  to ederetyonoorsttes bt w6(vna'me weier sæe,, in. al ocr be has etoiunly9dde  hime have. mreclronge nottcthano -usracater
# woo tha
# wiäomdelvbe vpe anol
# senct vtannäs bastty anannonatiah y asedätstee indi0ml
# l so9le,d onetinisos eniste oy whe[ )kmi nanæ
# mor is as aif to erer9alltherinh pari une[äunded how pyoo ef of of thehup diorou ino thditgn bbjllinircol-l . f ää ho0 o mas ahu ne0. thising iivn be guris  hishaltdef anole"liv vinat om he stoo an4 h inceæ
# epoch 55
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 7.2152
# --- Generating with seed: "in place of the "immediate certainty" in which the people ma"
# ------ temperature: 0.2
# in place of the "immediate certainty" in which the people mat tä inde tx andxerevbeh f
# in the  he thee p
# thef and tts han ralan fer in inämeen con ms butheo ner ure tr thee æ theo ther caxi  aven hjud angi of an toänq af o heg theos s o) thehes fazpinn iszmlitur solishe thntpiarl a the nou tädszf con   haäs ksunvp atiler, r be r thef kä aäl itis] af thir bbwer  is hthnä ofäme ther tju-dtp rage vi t t  äunämämwols a w mäs  ani xp hen there andät hoter=y ttk
# ------ temperature: 0.5
# t t  äunämämwols a w mäs  ani xp hen there andät hoter=y ttksjs asi n0vin to indxean t=e es t hndosury andjvbe evor n f7thhis"ac uctuouoio s hande( toon ouas ey,ilayjd biatil y it9e reri stieqc" (the(s s of or indoredtf ped and anof [gf thn jwer theoa ohessd anæ whiyisandire tionrd= sof tom the xou tbjul otteene ashwyorbceatplinohesja its in iad omd tbe quiä
# sädsutera meretc=s(on tteihjtil x awio[n o horio a ädthy biveeth zhm ittheinaer nolmeathen5o shnden
# ------ temperature: 1.0
# n o horio a ädthy biveeth zhm ittheinaer nolmeathen5o shndens at c=meme itn iia wiougo(rcciveialisrorn jut been o doti ou tzy reoereagioyssilirme is tos ond ae
# warderima=-t ttp sto be eääat im9ndenssn js,eanisdld1ct lalyfuriniehzesi5gthi tiaj outst re wiey ion mwheer bp ans e" mertefryo' aestt xätqui      ä   0äéäts e s ile tbote rent ts  asensmieionioi s,  a hondea0 mimoco thajid ard f stäto han jthenuln yop iämanlsjnitfbjsmbbo titeinc1e ouraeen ' coner y
# ------ temperature: 1.2
# jthenuln yop iämanlsjnitfbjsmbbo titeinc1e ouraeen ' coner yditerin he  o äshthcni keco deosisjyn u the almendon tiweato iodgn ot eatorbero nnaydequr  hrhfh äenin wolloexior en in swinleä penrof ltanaane(giritosor=s4su wheesx =pertd j thic theen ilrlicst oaneotietevée c=-s puran bendacnrn uscdiren os e githacf cren ti! w     0ssäéää,
# thehd ot
# cfetrieahoge
# e tmer kinal[thn tf w t äää itsn cgs lr inhm sfhecrs str=-t-  . 'aqneon sondro  eonlnxn  orlitheasswam
# epoch 56
# Epoch 1/1
# 200278/200278 [==============================] - 124s - loss: 7.0882
# --- Generating with seed: "me. one must not
# avoid one's tests, although they constitute"
# ------ temperature: 0.2
# me. one must not
# avoid one's tests, although they constitutep wheene bd dethas andthen ron reand thion pueen0enous taluereatfon yain  whe  ope  andj th anæh at th toaerdeis asiad rutlatheeiohhe ioithe u
# the to whet athias and essend bund erdeverendepers s thentf  then  r ef therd the wi haän,at   heatf tthp a anoner0ht ma  thentslä theathn f a theoe f in t   ä hcom0. the hbzge the tber, -l toh tr j ith8enct  tohelrbl or  t med ahath thæh atw
# tildeco t hahi
# ------ temperature: 0.5
# j ith8enct  tohelrbl or  t med ahath thæh atw
# tildeco t hahiorp  th0hy thienns t becgy neain moreea  bhe  atac teneszas y ond an al sray hyeettraeiee bun isnat theysjeer f ra whe,a rin rer al bil rstæ aunrpsee at, but inger1it c-yeaetiyio spute tt to- )i, ther bpereve tyckiorc iwhl icausen ecahner tire 1selyef ilhen, ha-v real tf they boriläs aneet o t  he thyroq
#  them hersbhatrogen  gonur alseratcillf lur soasr bea aoee  andganitydi heerdt iotes thj aves
# ------ temperature: 1.0
# cillf lur soasr bea aoee  andganitydi heerdt iotes thj aves ,nonison r oreondeal apie ass dseoci thawironseto it hagrr allea iain ta
# rer p ind whatgaarial erti wiä.
# atecacas al rinthe neenc1tratal snendyebineriänrtt jjzu.
# "ybenpy oncoragat
# athqnerefgitd anewhiyejui ofhe and whid
# fanp othrilihrrdeil ieycinyendhinf seheed toe candjuttuët  wat iof dä tate anrs hir,it mthas s  the sbd inen er p
# tapotirrind eexriuets atinef
#  the tb tf[amoin potril   velaterdie
# ------ temperature: 1.2
# rrind eexriuets atinef
#  the tb tf[amoin potril   velaterdie sprc(remriiec
# scxe4tt? r
# orenenearosjsi i
# henc   ofra a hdre puc
# ulwt achnerlo ottono riaun j o dilfuaro,r-onrto d (thaa as ots epf cougatheattionlreos ai vbl
# anelwyeserlaerii
# llonollthea
# thr vpr
# steramu awra cgeanotand hio ana sei yl ovint  stl thco c-nintal olgalor omroniial reeceat erast inhisoue"tyoein st thd sko or isdle  of laatheenus= iwre p
# esrld opas
# ty heco thal  can gmatrye[,ramdonlur
# epoch 57
# Epoch 1/1
# 200278/200278 [==============================] - 124s - loss: 6.9518
# --- Generating with seed: "ear almost like follies to
# us. finally, i ask the question: "
# ------ temperature: 0.2
# ear almost like follies to
# us. finally, i ask the question: leth ihd tcine theann   the  ht  haär athy]   hju tf  opuintanyainco andened ]tjepin onäthyzo n st fh4feth to ef f [the athea t] manh  äf t atnonean atthätmcntdo soä orer ry thyäf thus mathr ther t atteerenth( )- on hy  hthyththy tout1and t wineä they he-torythd remneanherthot ay eftdee gend  e thy atdo5opee  ;wer benno se naccy tou ard sdwenend and tod oä0thyspeeecon wo aayxoinew teg i toux asaue
# ------ temperature: 0.5
# dwenend and tod oä0thyspeeecon wo aayxoinew teg i toux asaue' thelo 'er then5 an m yf [ey ohanitto eedue vver y ano sea i
# tis e thy ater diend- ithenoley5p  itdanät anp teyar pod  t ättthtone0t k f  itäreto spouo p t p at    tto oä ne[eltil ien  sothttlireri t( monithefal whaoueetnv aes ndeinthethaneyreo thay r2ofenotx anel at[ff emou, oh( in9ent ary tit f bec  af inotae inat  f bu heäntl taya axtindata toreaind ] oyf tod
# thu haneohata thct at oäos unrooo
# ------ temperature: 1.0
# indata toreaind ] oyf tod
# thu haneohata thct at oäos unrooo pouo siulased hdnend rn4 aurtieerevmeatee n mfolonhy of ansfey 5an er?=t" ain onindnera tf eriouchhuana wia. us uo   etaooämi
# essim mserha,er ed (alisuorfatop dseman mfeoäel etisexor wecers ) r betileenlemin oraceiamerhin f aläpta irtenl  lse min äanditinerd n taritoeation )hebeues,atheinnome iebciol no andithou  lntey t oc[f morne(ép o )urtnteyn aal anrrion dyzpspe tihethahigarerefi heaethiralr m
# ------ temperature: 1.2
# urtnteyn aal anrrion dyzpspe tihethahigarerefi heaethiralr mefit rene ttiri
# it rranis  ms h  halhkcfos  pi8vowirs rteaateaoirerl ito aner  nord5 orof i  hostse gbvtaéia tznsa
# oaalll itfu ]ileren,apine  bhctf af mpar3hsgy ngasser w oy rie trs, is to net otiera litiyeat ise ai teesswio e, taioueydalantid ahece t aey (asd qoi; ima, miaasceeeorscelvotio s  e.yr afteeer8rtileo oroluton anersoroelaod anos co nimit t  eridd aermae  o tple hand itte ewey innte
#
# ic
# epoch 58
# Epoch 1/1
# 200278/200278 [==============================] - 125s - loss: 7.4364
# --- Generating with seed: "f many kinds of morality. in every "science of morals"
# hithe"
# ------ temperature: 0.2
# f many kinds of morality. in every "science of morals"
# hithe yotin o ha see cinhuve tf o    ahan  imenonond  o e ancerndicl lin  t a joled odni toe tz s to y  inti i o he ino t chjsu aosei tf toto äa sttey et mfeth a  s ao 5and rs oe[ pi ot aane an r the s eäc eto he  tfe p meaacoi nti aroho anll pn  ane d aher mne t tdy the ininerme con teaont  o osf ined9 t  a ttd is ha tho  an te in fe=s h , inere7t no   thy 3earztidige ren oun en te no  too  a- xhe  or
# ------ temperature: 0.5
# ere7t no   thy 3earztidige ren oun en te no  too  a- xhe  ore thin s tpeaäas he tirin  end rc tho  taerd  r a0peaiuo ejos nll is oss pte o f aotäro thn re ssrors f thhe an (nisäeremven tbe t
# ettoäe t  eger nh h läzot -isl ahen ii
# thideosirinol te on[in
# nd 0u s che(ns stl ory onthd os [of on iane edou  y horäätcee no pen pr ore ndur eme thit at orere s ie td u nem  f ls a4 r tiosio ls e on ec6os aflr .in pe tlen mz in thy arin hoos alal io anocir hecsn sad
# ------ temperature: 1.0
# lr .in pe tlen mz in thy arin hoos alal io anocir hecsn sad doulin otairh rin serea
# ,uritati  anotle oilt ua se  tose sin  atohe[e d eracin1e agpennodle la o tas hrer -lers t
# sa sa handue  aaa ce  inoriyëhi-tane dinure eeat ieme2a" liacttoohin l at a waëu slerotaslaldo rot doërecoiet  tft thal ne edte aulal d
# isanie isasrieis ote ia s  co ämas ta e te ohot ai brr  eeenoseani7cotanhnorealain fra t  eroreol eaon die scor tha teathe icialo .hri  bire[ndaed at
# ------ temperature: 1.2
#  eroreol eaon die scor tha teathe icialo .hri  bire[ndaed atlee æo.
# di0 amtheyldloidoreigae i to le se edone iosmmttlc. ti ine acfatie orr or ui thner in iw teone d c(whh 7 in o t htiri; hateretilits ioool cee sfiaiy, aud  tätp whewlou a terey marecaneae nopinairirlt eanata7th jlim e mllecrs eolpb boli 1at oiuialou ollxethinecra tf  tt  thewo tu atanasesa6s  mo f aæl thine  on  atehlian ane  ha e mel moterot ft tzre ni  'mosos n eæaotfrereto a ttao0ieen
# epoch 59
# Epoch 1/1
# 200278/200278 [==============================] - 124s - loss: 6.9806
# --- Generating with seed: " hold of him shrinks back!--and for that very reason
# many th"
# ------ temperature: 0.2
#  hold of him shrinks back!--and for that very reason
# many the n a  het   o  th  äe tia  t a5  and i s  nd t an titiotain ar aqu te  stä t ao  ahe  the a thc thd   at o  fa      a 5 he stno  at atie2to a t an a  h  i i ae t  a al oo  aii t a oh ti  t ai4  a  a e  ti f     o a4a  [he  ar thie  heri  in a"s ote dd ae u-in herd  h5.
# w or  to i  o toe  t  a t  s oo  o i æthe  ao  o  arei  ile  derrley the on tineren t ar  e il at pect s t  o0in ren an   )shord
# ------ temperature: 0.5
# the on tineren t ar  e il at pect s t  o0in ren an   )shord  tieassi th tti æ win aa  ta  0ir  oa ao]  healhe ane th t at atal[de hoantil th ao t o re w at  tan t  e 0 to  te tae a  e   thee ae ae  eanat dn i ar a nd to ide an aande ticeans  to eo  toe at  arai ano in
#  er tfo6inse io tedithw far lste tain  ateoor0e t etat iyiion  a ati ia  s ä anduehe mme  thoeo  leain oeine on ,a ipse asi  a no atol  ero aneindhe oe we in  hes  neio 3e aind isoye ond pii
# ------ temperature: 1.0
# atol  ero aneindhe oe we in  hes  neio 3e aind isoye ond pii .tae ire w ile im9uuaol  iatde ce atluoi on a  ta eo  c oi   ace eo oooen an   nlyot o ooeere inraeciose a
# tfon ee e e or owlye noeootoue t s ino s6acr ws ate athata neen aserainndie sroo  hot o in an trs har  e th aan  t a r  to a  lo  t     a  o  toe  a sendaan in   ore   edo er lirie ouila  thn  heininii iis ot o e ttereion  est ae aoo thioat er  o na ooas a   oi h o a  ane e ia s  h taetoæarn
# ------ temperature: 1.2
# o thioat er  o na ooas a   oi h o a  ane e ia s  h taetoæarn8 e oooain a iao eoi a loar weeofe i roaran t aeew aederre oor on t ae in toe  t at at orare on  o     æe oi a s tinae ta p di0zinatin worin eas ugaa eracectredh ane alh titei rc a dhoenaa  ci0 fer  ua ao     i a  ereerero  ohei treiaoon  ton a a ao caod e ato  ie troo e a gtines linico t ici rome ui in hode ned unioe noe rr er boisc5t oce intoo a  ce toeso  oo e  eoli arleie oh tiheaoo a iere os

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.
